# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioAldamaG/MachineLearning/blob/main/Unidad1/Practica_1_DataWranling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine y Deep Learning
#
# # Unidad 1
#
# ## Practica 1: **DataWranling**
#
# ### Docente: Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Antonio Manuel Aldama Gándara

# %%
import pandas as pd
import matplotlib as plt
from matplotlib import pyplot
import numpy as np

# %%
autos = pd.read_csv("AutosDatosSucios.csv")
autos.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
autos = pd.read_csv("AutosDatosSucios.csv")
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak-rpm           205 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
autos = pd.read_csv("AutosDatosSucios.csv")
autos.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
# 5        sedan          fwd           front        99.8  ...          136
# 6        sedan          fwd           front       105.8  ...          136
# 7        wagon          fwd           front       105.8  ...          136
# 8        sedan          fwd           front       105.8  ...          131
# 9    hatchback          4wd           front        99.5  ...          131
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
# 5         mpfi  3.19     3.4               8.5        110      5500       19
# 6         mpfi  3.19     3.4               8.5        110      5500       19
# 7         mpfi  3.19     3.4               8.5        110      5500       19
# 8         mpfi  3.13     3.4               8.3        140      5500       17
# 9         mpfi  3.13     3.4               7.0        160      5500       16
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
# 5          25  15250
# 6          25  17710
# 7          25  18920
# 8          20  23875
# 9          22      ?
#
# [10 rows x 26 columns]

# %%
autos.replace("?", np.nan, inplace = True)
autos.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
autos["normalized-losses"].isnull().value_counts()
# Out:
# normalized-losses
# False    164
# True      41
# Name: count, dtype: int64

# %%
autos.isna().sum().sort_values()
# Out:
# symboling             0
# make                  0
# fuel-type             0
# aspiration            0
# drive-wheels          0
# body-style            0
# wheel-base            0
# engine-location       0
# height                0
# curb-weight           0
# length                0
# width                 0
# engine-type           0
# num-of-cylinders      0
# fuel-system           0
# engine-size           0
# highway-mpg           0
# compression-ratio     0
# city-mpg              0
# num-of-doors          2
# peak-rpm              2
# horsepower            2
# bore                  4
# stroke                4
# price                 4
# normalized-losses    41
# dtype: int64

# %%
avg_norm_loss = autos["normalized-losses"].astype("float").mean(axis=0)
print("Promedio de normalized-losses:", avg_norm_loss)
# Out:
# Promedio de normalized-losses: 122.0

# %%
autos ["normalized-losses"].replace(np.nan, avg_norm_loss, inplace=True)
# Out:
# /tmp/ipykernel_2321/1294268921.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos ["normalized-losses"].replace(np.nan, avg_norm_loss, inplace=True)

# %%
avg_bore = autos["bore"].astype("float").mean(axis=0)
print("Promedio de bore:", avg_bore)
# Out:
# Promedio de bore: 3.3297512437810943

# %%
autos ["bore"].replace(np.nan, avg_bore, inplace= True)
# Out:
# /tmp/ipykernel_2321/2119863730.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos ["bore"].replace(np.nan, avg_bore, inplace= True)

# %%
avg_stroke = autos["stroke"].astype("float").mean(axis=0)
print("Promedio de stroke", avg_stroke)
# Out:
# Promedio de stroke 3.255422885572139

# %%
autos ["stroke"].replace(np.nan, avg_stroke, inplace= True)
# Out:
# /tmp/ipykernel_2321/2264295998.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos ["stroke"].replace(np.nan, avg_stroke, inplace= True)

# %%
avg_horsepower = autos["horsepower"].astype("float").mean(axis=0)
print("Promedio de horsepower:", avg_horsepower)
# Out:
# Promedio de horsepower: 104.25615763546799

# %%
autos ["horsepower"].replace(np.nan, avg_horsepower, inplace= True)
# Out:
# /tmp/ipykernel_2321/183436702.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos ["horsepower"].replace(np.nan, avg_horsepower, inplace= True)

# %%
avg_peakrpm = autos["peak-rpm"].astype("float").mean(axis=0)
print("Promedio de peakrpm:", avg_peakrpm)
# Out:
# Promedio de peakrpm: 5125.369458128079

# %%
autos ["peak-rpm"].replace(np.nan, avg_peakrpm, inplace= True)
# Out:
# /tmp/ipykernel_2321/58287007.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos ["peak-rpm"].replace(np.nan, avg_peakrpm, inplace= True)

# %%
autos ["num-of-doors"].value_counts()
# Out:
# num-of-doors
# four    114
# two      89
# Name: count, dtype: int64

# %%
autos["num-of-doors"].replace(np.nan, "four", inplace=True)
# Out:
# /tmp/ipykernel_2321/2348393866.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos["num-of-doors"].replace(np.nan, "four", inplace=True)

# %%
autos.dropna(subset=["price"], axis=0, inplace=True)
autos.reset_index(drop=True, inplace=True)

# %%
autos[["bore", "stroke"]] = autos [["bore", "stroke"]].astype("float")
autos [["noremalized_losses"]] = autos [["normalized-losses"]].astype("int")
autos [["price"]] = autos[["price"]].astype
autos[["peak-rpm"]] = autos[["peak-rpm"]].astype("float")

# %%
autos["city-L/100km"] = 235 / autos["city-mpg"]

# %%
autos["highway-mpg"] = 235 / autos["highway-mpg"]
autos.rename(columns={"highway-mpg":"high-L/100km"}, inplace=True)
autos.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  bore  stroke  \
# 0  convertible          rwd           front        88.6  ...  3.47    2.68
# 1  convertible          rwd           front        88.6  ...  3.47    2.68
# 2    hatchback          rwd           front        94.5  ...  2.68    3.47
# 3        sedan          fwd           front        99.8  ...  3.19    3.40
# 4        sedan          4wd           front        99.4  ...  3.19    3.40
#
#    compression-ratio  horsepower peak-rpm city-mpg  high-L/100km  \
# 0                9.0         111   5000.0       21      8.703704
# 1                9.0         111   5000.0       21      8.703704
# 2                9.0         154   5000.0       19      9.038462
# 3               10.0         102   5500.0       24      7.833333
# 4                8.0         115   5500.0       18     10.681818
#
#                                                price  noremalized_losses  \
# 0  <bound method NDFrame.astype of      price\n0 ...                 122
# 1  <bound method NDFrame.astype of      price\n0 ...                 122
# 2  <bound method NDFrame.astype of      price\n0 ...                 122
# 3  <bound method NDFrame.astype of      price\n0 ...                 164
# 4  <bound method NDFrame.astype of      price\n0 ...                 164
#
#    city-L/100km
# 0     11.190476
# 1     11.190476
# 2     12.368421
# 3      9.791667
# 4     13.055556
#
# [5 rows x 28 columns]

# %%
autos["length"] = autos["length"] / autos["length"].max()
autos["width"] = autos["width"] / autos["width"].max()
autos["height"] = autos["height"] / autos["height"].max()

# %%
autos[["length", "width", "height"]].head()
# Out:
#      length     width    height
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %%
autos["fuel-type"].value_counts()
# Out:
# fuel-type
# gas       181
# diesel     20
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
autos["fuel-type_Code"] = le.fit_transform(autos["fuel-type"])

# %%
autos.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  stroke  \
# 0  convertible          rwd           front        88.6  ...    2.68
# 1  convertible          rwd           front        88.6  ...    2.68
# 2    hatchback          rwd           front        94.5  ...    3.47
# 3        sedan          fwd           front        99.8  ...    3.40
# 4        sedan          4wd           front        99.4  ...    3.40
#
#    compression-ratio  horsepower  peak-rpm city-mpg high-L/100km  \
# 0                9.0         111    5000.0       21     8.703704
# 1                9.0         111    5000.0       21     8.703704
# 2                9.0         154    5000.0       19     9.038462
# 3               10.0         102    5500.0       24     7.833333
# 4                8.0         115    5500.0       18    10.681818
#
#                                                price noremalized_losses  \
# 0  <bound method NDFrame.astype of      price\n0 ...                122
# 1  <bound method NDFrame.astype of      price\n0 ...                122
# 2  <bound method NDFrame.astype of      price\n0 ...                122
# 3  <bound method NDFrame.astype of      price\n0 ...                164
# 4  <bound method NDFrame.astype of      price\n0 ...                164
#
#    city-L/100km  fuel-type_Code
# 0     11.190476               1
# 1     11.190476               1
# 2     12.368421               1
# 3      9.791667               1
# 4     13.055556               1
#
# [5 rows x 29 columns]

# %%
autos["fuel-type_Code"].value_counts()
# Out:
# fuel-type_Code
# 1    181
# 0     20
# Name: count, dtype: int64

# %%
variable_dummy1 = pd.get_dummies(autos["fuel-type"])
variable_dummy1.head()
# Out:
#    diesel   gas
# 0   False  True
# 1   False  True
# 2   False  True
# 3   False  True
# 4   False  True

# %%
mapeo_dicc = {'diesel ' :0, 'gas':1}

autos['fuel-type-map' ] = autos["fuel-type"].map(mapeo_dicc)

# %%
autos.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  \
# 0  convertible          rwd           front        88.6  ...
# 1  convertible          rwd           front        88.6  ...
# 2    hatchback          rwd           front        94.5  ...
# 3        sedan          fwd           front        99.8  ...
# 4        sedan          4wd           front        99.4  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg high-L/100km  \
# 0                9.0         111    5000.0        21     8.703704
# 1                9.0         111    5000.0        21     8.703704
# 2                9.0         154    5000.0        19     9.038462
# 3               10.0         102    5500.0        24     7.833333
# 4                8.0         115    5500.0        18    10.681818
#
#                                                price  noremalized_losses  \
# 0  <bound method NDFrame.astype of      price\n0 ...                 122
# 1  <bound method NDFrame.astype of      price\n0 ...                 122
# 2  <bound method NDFrame.astype of      price\n0 ...                 122
# 3  <bound method NDFrame.astype of      price\n0 ...                 164
# 4  <bound method NDFrame.astype of      price\n0 ...                 164
#
#   city-L/100km  fuel-type_Code  fuel-type-map
# 0    11.190476               1            1.0
# 1    11.190476               1            1.0
# 2    12.368421               1            1.0
# 3     9.791667               1            1.0
# 4    13.055556               1            1.0
#
# [5 rows x 30 columns]

# %%
autos["horsepower"] = autos["horsepower"].astype(int, copy= True)

# %%
plt.pyplot.hist( autos["horsepower"] )
plt.pyplot.xlabel("caballos de fuerza")
plt.pyplot.ylabel("cantidad")
plt.pyplot.title("contenedores horsepower")
# Out:
# Text(0.5, 1.0, 'contenedores horsepower')

# %%
plt.pyplot.hist( autos["horsepower"], bins = 3)
plt.pyplot.xlabel("caballos de fuerza")
plt.pyplot.ylabel("cantidad")
plt.pyplot.title("contenedores horsepower")
# Out:
# Text(0.5, 1.0, 'contenedores horsepower')

# %%
bins = np.linspace(min ( autos["horsepower"]), max(autos["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
grupos = ["low", "medium", "high"]

# %%
autos["horsepower-binned"] = pd.cut(autos["horsepower"], bins, labels=grupos, include_lowest=True)
autos[["horsepower", "horsepower-binned"]].head(10)
# Out:
#    horsepower horsepower-binned
# 0         111               low
# 1         111               low
# 2         154            medium
# 3         102               low
# 4         115               low
# 5         110               low
# 6         110               low
# 7         110               low
# 8         140            medium
# 9         101               low

# %%
autos["horsepower-binned"].value_counts()
# Out:
# horsepower-binned
# low       153
# medium     43
# high        5
# Name: count, dtype: int64

# %%
pyplot.bar(grupos, autos["horsepower-binned"].value_counts())

plt.pyplot.xlabel("Caballos de Fuerza")
plt.pyplot.ylabel("Cantidad")
plt.pyplot.title("Contenedores horsepower")
# Out:
# Text(0.5, 1.0, 'Contenedores horsepower')

# %%
autos.to_csv("autos_corregidos_csv", index = False)
